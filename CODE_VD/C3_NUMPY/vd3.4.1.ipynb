# %%
import numpy as np 
import time
arr = np.arange(10000000,dtype=np.int64)
start_time = time.time()
total = np.int64(0)
for num in arr:
    total += num
end_time = time.time()
elapsed_time_loop = end_time - start_time
print("Tổng các phần tử mảng arr khi sử dụng vòng lặp: ", total)
print("Thời gian(S) khi suwe dụng vòng lặp:",elapsed_time_loop)
# tính tổng 
start_time=time.time()
total = np.sum(arr)
end_time = time.time()
elapsed_time_npsum = end_time - start_time
print("Tổng các phần tử mảng arr khi sử dụng hàm np.sum():", total) 
print("Thời gian (giây) khi sử dụng np.sum():", elapsed_time_npsum) 
num_times_faster = elapsed_time_loop / elapsed_time_npsum 
print("Sử dụng vòng lặp chậm hơn: ~",int(num_times_faster),"lần")
# Out:
# Tổng các phần tử mảng arr khi sử dụng vòng lặp:  49999995000000
# Thời gian(S) khi suwe dụng vòng lặp: 1.1749095916748047
# Tổng các phần tử mảng arr khi sử dụng hàm np.sum(): 49999995000000
# Thời gian (giây) khi sử dụng np.sum(): 0.005187511444091797
# Sử dụng vòng lặp chậm hơn: ~ 226 lần
