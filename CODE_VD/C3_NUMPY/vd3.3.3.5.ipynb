# %%
import numpy as np
x = np.array([1,2,3]) # tạo mảng 1 chiều x 
x.reshape((1,3)) # trả về mảng 2d, nhưng 0 lưu
# mã lệnh này kh làm thay đổi x - nó chỉ  tạo và bỏ đi 1 bản sao 2d
x[np.newaxis,:] # tạo mma trạn hành 1x3 dử dụng np.nwaxis
x
np.newaxis is None
## cú pháp 
y = x[np.newaxis,:]
print("Ma trận x ban đầu:",x)
print("Ma trận sau khi thêm cột:",y)
##
z = x[:,np.newaxis]
print("Ma trận x ban đầu:",x)
print("MA trận z sau khi thêm cột:",z)
# Out:
# Ma trận x ban đầu: [1 2 3]
# Ma trận sau khi thêm cột: [[1 2 3]]
# Ma trận x ban đầu: [1 2 3]
# MA trận z sau khi thêm cột: [[1]
#  [2]
#  [3]]
