# %%
import pandas as pd 
population_dict = {
    'Hà Nội:':833803,
    "Quảng Ninh:":1358085,
    'Nam Định:':1836270,
    "TP Hồ Chí Minh:": 1195490

}
population = pd.Series(population_dict, name="Dân số/Thành Phố")
print(population)
# Out:
# Hà Nội:             833803
# Quảng Ninh:        1358085
# Nam Định:          1836270
# TP Hồ Chí Minh:    1195490
# Name: Dân số/Thành Phố, dtype: int64

# %%
print("Dân số Hà Nội:", population['Hà Nội:'])
# Out:
# Dân số Hà Nội: 833803

# %%
# ví dụ về value
print("Dữ liệu dân số: ",population.values)
# Out:
# Dữ liệu dân số:  [ 833803 1358085 1836270 1195490]

# %%
# index 
print(population.index)
# Out:
# Index(['Hà Nội:', 'Quảng Ninh:', 'Nam Định:', 'TP Hồ Chí Minh:'], dtype='object')

# %%
print(population.name)
# Out:
# Dân số/Thành Phố
