# %%
import pandas as pd
area_dict = {'Hà Nội':3358.9,
             'Quảng Ninh':6177.7,
             'Nam Định':1668}
area = pd.Series(area_dict)
area
# Out:
# Hà Nội        3358.9
# Quảng Ninh    6177.7
# Nam Định      1668.0
# dtype: float64
