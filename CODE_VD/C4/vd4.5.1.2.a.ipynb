# %%
import numpy as np
import pandas as pd 
s1 = pd.Series([2,4,6],index=['a','b','c'])
s2 = pd.Series([1,3,5],index=['b','c','d'])
s1
# Out:
# a    2
# b    4
# c    6
# dtype: int64

# %%
s2
# Out:
# b    1
# c    3
# d    5
# dtype: int64

# %%
s1 + s2
# Out:
# a    NaN
# b    5.0
# c    9.0
# d    NaN
# dtype: float64

# %%
s3 = pd.Series([2,4,6],index=['a','b','c'])
s4 = pd.Series([1,3,5],index=['b','c','d'])
s3
# Out:
# a    2
# b    4
# c    6
# dtype: int64

# %%
s4
# Out:
# b    1
# c    3
# d    5
# dtype: int64

# %%
s3.add(s4,fill_value=0) # fill các giá trị thieeus = 0
# Out:
# a    2.0
# b    5.0
# c    9.0
# d    5.0
# dtype: float64

# %%
population = pd.Series({'TP HCM':8993082,
                         'Hà Nội': 8330000,
                         'Thanh Hóa':3720000,
                         'Nghệ An':341000,
                         'Đồng Nai':3097107})
area = pd.Series({'Nghệ An':16493.8,
                  'Gia Lai':15536.9,
                  'Sơn La':14174.4,
                  'Đắk Lak':13030.5,
                  'Thanh Hóa':11132.2})
print("\nTop 5 tỉnh thành đông dân nhất Vn:\n",population)
print("\nTop 5 tỉnh thành S lớn nhất VN:\n",area)
# Out:
# Top 5 tỉnh thành đông dân nhất Vn:
#  TP HCM       8993082
# Hà Nội       8330000
# Thanh Hóa    3720000
# Nghệ An       341000
# Đồng Nai     3097107
# dtype: int64
#
# Top 5 tỉnh thành S lớn nhất VN:
#  Nghệ An      16493.8
# Gia Lai      15536.9
# Sơn La       14174.4
# Đắk Lak      13030.5
# Thanh Hóa    11132.2
# dtype: float64

# %%
density = area[:5]/population[:5]
print("Mật độ dân số tỉnh thành Vn:\n",density)
# Out:
# Mật độ dân số tỉnh thành Vn:
#  Gia Lai           NaN
# Hà Nội            NaN
# Nghệ An      0.048369
# Sơn La            NaN
# TP HCM            NaN
# Thanh Hóa    0.002993
# Đắk Lak           NaN
# Đồng Nai          NaN
# dtype: float64
