# %%
import pandas as pd 
tinh = ['Hà Nội','Hà Nội','Đà Nẵng','Đà Nẵng']
nam = [2023,2024,2023,2024]
idx = pd.MultiIndex.from_arrays([tinh,nam], names=['Tỉnh/Tp'])
print()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 4
#       2 tinh = ['Hà Nội','Hà Nội','Đà Nẵng','Đà Nẵng']
#       3 nam = [2023,2024,2023,2024]
# ----> 4 idx = pd.MultiIndex.from_arrays([tinh,nam], names=['Tỉnh/Tp'])
#       5 print(idx)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\multi.py:538, in MultiIndex.from_arrays(cls, arrays, sortorder, names)
#     535 if names is lib.no_default:
#     536     names = [getattr(arr, "name", None) for arr in arrays]
# --> 538 return cls(
#     539     levels=levels,
#     540     codes=codes,
#     541     sortorder=sortorder,
#     542     names=names,
#     543     verify_integrity=False,
#     544 )
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\multi.py:357, in MultiIndex.__new__(cls, levels, codes, sortorder, names, dtype, copy, name, verify_integrity)
#     354 result._names = [None] * len(levels)
#     355 if names is not None:
#     356     # handles name validation
# --> 357     result._set_names(names)
#     359 if sortorder is not None:
#     360     result.sortorder = int(sortorder)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\multi.py:1628, in MultiIndex._set_names(self, names, level, validate)
#    1626         raise ValueError("Length of names must match length of level.")
#    1627     if level is None and len(names) != self.nlevels:
# -> 1628         raise ValueError(
#    1629             "Length of names must match number of levels in MultiIndex."
#    1630         )
#    1632 if level is None:
#    1633     level = range(self.nlevels)
#
# ValueError: Length of names must match number of levels in MultiIndex.
