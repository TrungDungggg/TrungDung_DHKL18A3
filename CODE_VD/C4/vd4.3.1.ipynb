# %%
import pandas as pd 
data = pd.Series([1.0,0.25,6.0,0.75]) # tạo series từ danh sách list 
print(data)
# Out:
# 0    1.00
# 1    0.25
# 2    6.00
# 3    0.75
# dtype: float64

# %%
data[1]
# Out:
# np.float64(0.25)

# %%
type(data)
# Out:
# pandas.core.series.Series

# %%
# truy cập các thuộc tính 
print("GIá trị(value): ",data.values)
# Out:
# GIá trị(value):  [1.   0.25 6.   0.75]

# %%
print("Chỉ mục(index): ",data.index)
# Out:
# Chỉ mục(index):  RangeIndex(start=0, stop=4, step=1)
