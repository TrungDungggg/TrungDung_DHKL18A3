# %%
import pandas as pd 
population_dict = {
    'Hà Nội:':833803,
    "Quảng Ninh:":1358085,
    'Nam Định:':1836270,
    "TP Hồ Chí Minh:": 1195490

}
population = pd.Series(population_dict, name="Dân số/Thành Phố")
print(population)
# Out:
# Hà Nội:             833803
# Quảng Ninh:        1358085
# Nam Định:          1836270
# TP Hồ Chí Minh:    1195490
# Name: Dân số/Thành Phố, dtype: int64

# %%
# truy cập theo phần tử index

print("Giá trị tại mục chỉ 2:",population[2])
# Out:
# Giá trị tại mục chỉ 2: 1836270
# C:\Users\Admin\AppData\Local\Temp\ipykernel_21136\636328916.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print("Giá trị tại mục chỉ 2:",population[2])

# %%
# cắt lát slicing
print("CÁc phần tử từ 1->2")
population[:1,:3]
# Out:
# CÁc phần tử từ 1->2
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 3
#       1 # cắt lát slicing
#       2 print("CÁc phần tử từ 1->2")
# ----> 3 population[:1,:3]
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:1165, in Series.__getitem__(self, key)
#    1162     key = np.asarray(key, dtype=bool)
#    1163     return self._get_rows_with_mask(key)
# -> 1165 return self._get_with(key)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:1175, in Series._get_with(self, key)
#    1170     raise TypeError(
#    1171         "Indexing a Series with DataFrame is not "
#    1172         "supported, use the appropriate DataFrame column"
#    1173     )
#    1174 elif isinstance(key, tuple):
# -> 1175     return self._get_values_tuple(key)
# ...
