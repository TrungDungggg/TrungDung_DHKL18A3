# %%
import tkinter as tk
from tkinter import font

root = tk.Tk()
root.title("Bài tập 7.3 - Định dạng Font")
root.geometry("400x200")


label = tk.Label(root, 
                 text="Trung Dũng uneti", 
                 font=("Arial", 30, "bold"))

label.pack(expand=True)

root.mainloop()
