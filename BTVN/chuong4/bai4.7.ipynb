# %%
import pandas as pd 
import numpy as np
np.random.seed(100) 
ser = pd.Series(np.random.randint(1, 5, [12]))
top2 = ser.value_counts().index[:2]
ser[ser.isin(top2) == False] = 'Other'
print(ser)
# Out:
# 0         1
# 1         1
# 2         4
# 3         4
# 4         4
# 5         4
# 6         1
# 7     Other
# 8     Other
# 9         1
# 10    Other
# 11    Other
# dtype: object
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7764\4199531380.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Other' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   ser[ser.isin(top2) == False] = 'Other'
