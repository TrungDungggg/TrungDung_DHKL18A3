# %%
import numpy as np 
import pandas as pd
ser = pd.Series(np.random.randint(1, 10, 35))
# đoạn code tạo số nguyên ngẫu nhiên từ 1 đến 9 có 35 số
# Chuyển thành DataFrame 7 hàng 5 cột
df = pd.DataFrame(ser.values.reshape(7, 5))
print(df)
# Out:
#    0  1  2  3  4
# 0  3  7  9  6  4
# 1  4  4  9  9  2
# 2  9  2  4  5  6
# 3  7  8  7  7  9
# 4  8  3  4  7  9
# 5  2  6  4  4  5
# 6  5  7  8  1  4
