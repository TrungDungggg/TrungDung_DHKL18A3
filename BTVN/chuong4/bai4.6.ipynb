# %%
import pandas as pd 
import numpy as np 
ser = pd.Series(np.take(list('abcdefgh'), np.random.randint(8, size=30)))
# giải thích 
# đoạn code tạo lấy chữ cái từ a đến h và random số ngẫu nhiên đến gán vào a đến h 
# tính số lần xuất hiện 
counts = ser.value_counts()
print(counts)
# Out:
# g    6
# f    6
# h    5
# a    4
# e    3
# c    3
# b    2
# d    1
# Name: count, dtype: int64
